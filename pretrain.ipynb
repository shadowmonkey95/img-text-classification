# %%
import pandas as pd
import re

# %%
trademark_codes = pd.read_csv('./data/csv/trademark_codes.csv') # 1586 rows x 2 columns: code + des
trademark_updated = pd.read_csv('./data/csv/trademark_updated.csv') # 158511 rows x 4 columns: serial No 
trademark = pd.read_csv('./data/csv/trademark.csv') # 158511 rows x 4 columns

# %%
# trademark_codes.head(5)
# trademark_updated.head(5)
# trademark_updated['Design Search Code(s)']
# trademark.loc[5, 'Design Search Code(s)']
trademark.head(10)
# Out:
#    serial No     Mark Literal Elements  \
# 0   71000233                       NaN
# 1   71002779                CAMPBELL'S
# 2   71012280               AUNT JEMIMA
# 3   71083280    WHEN IT RAINS IT POURS
# 4   71124272                       NaN
# 5   71149311                  SLEEP-ON
# 6   71154587       EVERY BIT A DELIGHT
# 7   71172379  ICE CREAM MAKERS' FRIEND
# 8   71173691                       BRH
# 9   71190472                       NaN
#
#                                  Description of Mark  \
# 0                                                NaN
# 1  The mark consists of a band, the upper half of...
# 2  THE TRADE-MARK CONSISTS OF THE REPRESENTATION ...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  THE PICTURE SHOWN IN THE ILLUSTRATION IS FANCI...
# 8                                                NaN
# 9                                                NaN
#
#                                Design Search Code(s)
# 0  02.03.04 -  Women, Pilgrims, women in colonial...
# 1  26.11.10 -  Rectangles divided once into two s...
# 2  02.03.01 -  Women - head, portraiture or busts...
# 3  01.15.07 -  Snow in a storm; Sleet; Rain; Hail...
# 4  02.03.13 -  Women, other women wearing folk, h...
# 5  02.05.05 -  Children, boy(s); Boys  02.05.06 -...
# 6  26.01.02 -  Plain single line circles; Circles...
# 7  02.01.04 -  Robes, men wearing; Shepherds; Rel...
# 8  24.15.10 -  More than one arrow; Arrows, more ...
# 9  26.05.21 -  Triangles that are completely or p...

# %%
trademark.loc[2, 'Design Search Code(s)']
# Out:
# '02.03.01 -  Women - head, portraiture or busts facing forward; Portraiture of women facing forward; Heads of women facing forward; Busts of women facing forward  02.03.15 -  Women wearing scarves on their heads; Scarves (women wearing on heads)'

# %%
def extract_codes_and_descriptions(text):
    if pd.isna(text):  # Handle NaN/None values
        return {}
        
    # Split by space + code pattern to separate multiple entries
    pattern = r'(\d{2}\.\d{2}\.\d{2})\s*-\s*([^0-9]+?)(?=\s+\d{2}\.\d{2}\.\d{2}|$)'
    matches = re.finditer(pattern, text.strip())
    
    codes_desc = {}
    for match in matches:
        code = match.group(1)
        description = match.group(2).strip()
        codes_desc[code] = description
    
    return codes_desc

# pretrain[pretrain['target_h2'].notna()]
extracted_tmp = extract_codes_and_descriptions(trademark.loc[2, 'Design Search Code(s)'])
# extracted_tmp = extract_codes_and_descriptions(trademark[trademark['serial No'] == "89002325"])
print(extracted_tmp)
# Out:
# {'02.03.01': 'Women - head, portraiture or busts facing forward; Portraiture of women facing forward; Heads of women facing forward; Busts of women facing forward', '02.03.15': 'Women wearing scarves on their heads; Scarves (women wearing on heads)'}

# %%
def categorize_codes_with_descriptions(codes_desc):
    h1_codes = {} 
    h2_codes = {}
    h3_codes = {}
    
    for code, desc in codes_desc.items():
        dot_count = code.count('.')
        if dot_count == 0:
            h1_codes[code] = desc
        elif dot_count == 1:
            h2_codes[code] = desc
        elif dot_count == 2:
            h3_codes[code] = desc
    
    return h1_codes, h2_codes, h3_codes

print(categorize_codes_with_descriptions(extracted_tmp))
# Out:
# ({}, {}, {'02.03.01': 'Women - head, portraiture or busts facing forward; Portraiture of women facing forward; Heads of women facing forward; Busts of women facing forward', '02.03.15': 'Women wearing scarves on their heads; Scarves (women wearing on heads)'})

# %%
def process_trademark_file(input_df, output_file):
    df = input_df.copy()
    string_columns = ['serial No', 'Design Search Code(s)']
    for col in string_columns:
        df[col] = df[col].astype(str).str.strip()
    
    output_data = []
    
    for _, row in df.iterrows():
        serial_no = row['serial No']
        design_codes = row['Design Search Code(s)']
        
        codes_desc = extract_codes_and_descriptions(design_codes)
        h1_codes, h2_codes, h3_codes = categorize_codes_with_descriptions(codes_desc)
        
        output_row = {
            'image_name': f'{serial_no}.jpg',
            'target': ','.join(codes_desc.keys()),
            'target_description': design_codes,
            'target_h1': ','.join(sorted(h1_codes.keys())),
            'target_h1_description': ' | '.join([f"{code} - {desc}" for code, desc in sorted(h1_codes.items())]),
            'target_h2': ','.join(sorted(h2_codes.keys())),
            'target_h2_description': ' | '.join([f"{code} - {desc}" for code, desc in sorted(h2_codes.items())]),
            'target_h3': ','.join(sorted(h3_codes.keys())),
            'target_h3_description': ' | '.join([f"{code} - {desc}" for code, desc in sorted(h3_codes.items())])
        }
        
        output_data.append(output_row)
    
    output_df = pd.DataFrame(output_data)
    output_df.to_csv(output_file, index=False)
    
process_trademark_file(trademark, "./data/csv/pretrain.csv")

# %%
pretrain = pd.read_csv('./data/csv/pretrain.csv')
pretrain
# Out:
#           image_name                                             target  \
# 0       71000233.jpg                02.03.04,02.03.14,02.03.21,02.09.06
# 1       71002779.jpg                                  26.11.10,26.11.21
# 2       71012280.jpg                                  02.03.01,02.03.15
# 3       71083280.jpg  01.15.07,02.05.04,02.09.06,10.03.03,19.07.25,2...
# 4       71124272.jpg                02.03.13,02.03.25,05.03.10,09.01.04
# ...              ...                                                ...
# 158506  89002321.jpg                         05.05.05,05.05.25,26.11.01
# 158507  89002322.jpg                                  05.05.05,05.05.25
# 158508  89002325.jpg                                           01.01.13
# 158509  89002386.jpg       01.15.05,10.01.04,23.01.03,24.15.10,26.01.17
# 158510  89002387.jpg  01.05.01,03.15.01,03.19.25,05.01.01,05.07.07,0...
#
#                                        target_description  target_h1  \
# 0       02.03.04 -  Women, Pilgrims, women in colonial...        NaN
# 1       26.11.10 -  Rectangles divided once into two s...        NaN
# 2       02.03.01 -  Women - head, portraiture or busts...        NaN
# 3       01.15.07 -  Snow in a storm; Sleet; Rain; Hail...        NaN
# 4       02.03.13 -  Women, other women wearing folk, h...        NaN
# ...                                                   ...        ...
# 158506  05.05.05 -  Daisies  05.05.25 -  Other flowers...        NaN
# 158507  05.05.05 -  Daisies  05.05.25 -  Iris  (flower...        NaN
# 158508  01.01.13 -  Stars - multiple stars with five p...        NaN
# 158509  01.15.05 -  Vapor; Steam; Smoke  10.01.04 -  P...        NaN
# 158510  01.05.01 -  Sun, rising or setting (partially ...        NaN
#
#         target_h1_description  target_h2  target_h2_description  \
# 0                         NaN        NaN                    NaN
# 1                         NaN        NaN                    NaN
# 2                         NaN        NaN                    NaN
# 3                         NaN        NaN                    NaN
# 4                         NaN        NaN                    NaN
# ...                       ...        ...                    ...
# 158506                    NaN        NaN                    NaN
# 158507                    NaN        NaN                    NaN
# 158508                    NaN        NaN                    NaN
# 158509                    NaN        NaN                    NaN
# 158510                    NaN        NaN                    NaN
#
#                                                 target_h3  \
# 0                     02.03.04,02.03.14,02.03.21,02.09.06
# 1                                       26.11.10,26.11.21
# 2                                       02.03.01,02.03.15
# 3       01.15.07,02.05.04,02.09.06,10.03.03,19.07.25,2...
# 4                     02.03.13,02.03.25,05.03.10,09.01.04
# ...                                                   ...
# 158506                         05.05.05,05.05.25,26.11.01
# 158507                                  05.05.05,05.05.25
# 158508                                           01.01.13
# 158509       01.15.05,10.01.04,23.01.03,24.15.10,26.01.17
# 158510  01.05.01,03.15.01,03.19.25,05.01.01,05.07.07,0...
#
#                                     target_h3_description
# 0       02.03.04 - Women, Pilgrims, women in colonial ...
# 1       26.11.10 - Rectangles divided once into two se...
# 2       02.03.01 - Women - head, portraiture or busts ...
# 3       01.15.07 - Snow in a storm; Sleet; Rain; Hail ...
# 4       02.03.13 - Women, other women wearing folk, hi...
# ...                                                   ...
# 158506  05.05.05 - Daisies | 05.05.25 - Other flowers;...
# 158507  05.05.05 - Daisies | 05.05.25 - Iris  (flower)...
# 158508  01.01.13 - Stars - multiple stars with five po...
# 158509  01.15.05 - Vapor; Steam; Smoke | 10.01.04 - Pi...
# 158510  01.05.01 - Sun, rising or setting (partially e...
#
# [158511 rows x 9 columns]

# %%
def fill_hierarchical_levels(df):
    # Create a copy of the input dataframe
    df_filled = df.copy()
    
    def extract_levels(target_str):
        if pd.isna(target_str):
            return [], [], []
            
        codes = target_str.split(',')
        h1_codes = set()
        h2_codes = set()
        h3_codes = codes  # h3 is same as target
        
        for code in codes:
            parts = code.split('.')
            if len(parts) >= 1:
                h1_codes.add(parts[0])
            if len(parts) >= 2:
                h2_codes.add('.'.join(parts[:2]))
                
        return (
            ','.join(sorted(h1_codes)),
            ','.join(sorted(h2_codes)),
            ','.join(sorted(h3_codes))
        )
    
    # Process each row
    for idx, row in df_filled.iterrows():
        if pd.isna(row['target_h1']) or pd.isna(row['target_h2']):  # Only fill if h1 or h2 is NaN
            h1, h2, h3 = extract_levels(row['target'])
            df_filled.at[idx, 'target_h1'] = h1
            df_filled.at[idx, 'target_h2'] = h2
            df_filled.at[idx, 'target_h3'] = h3
    
    return df_filled

# Use the function
pretrain_filled = fill_hierarchical_levels(pretrain)

# Save to new CSV
pretrain_filled.to_csv('./data/csv/pretrain_fill.csv', index=False)
# Out:
# /tmp/ipykernel_477497/3048616532.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '02' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_filled.at[idx, 'target_h1'] = h1
# /tmp/ipykernel_477497/3048616532.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '02.03,02.09' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_filled.at[idx, 'target_h2'] = h2

# %%
pretrain_filled
# Out:
#           image_name                                             target  \
# 0       71000233.jpg                02.03.04,02.03.14,02.03.21,02.09.06
# 1       71002779.jpg                                  26.11.10,26.11.21
# 2       71012280.jpg                                  02.03.01,02.03.15
# 3       71083280.jpg  01.15.07,02.05.04,02.09.06,10.03.03,19.07.25,2...
# 4       71124272.jpg                02.03.13,02.03.25,05.03.10,09.01.04
# ...              ...                                                ...
# 158506  89002321.jpg                         05.05.05,05.05.25,26.11.01
# 158507  89002322.jpg                                  05.05.05,05.05.25
# 158508  89002325.jpg                                           01.01.13
# 158509  89002386.jpg       01.15.05,10.01.04,23.01.03,24.15.10,26.01.17
# 158510  89002387.jpg  01.05.01,03.15.01,03.19.25,05.01.01,05.07.07,0...
#
#                                        target_description       target_h1  \
# 0       02.03.04 -  Women, Pilgrims, women in colonial...              02
# 1       26.11.10 -  Rectangles divided once into two s...              26
# 2       02.03.01 -  Women - head, portraiture or busts...              02
# 3       01.15.07 -  Snow in a storm; Sleet; Rain; Hail...  01,02,10,19,26
# 4       02.03.13 -  Women, other women wearing folk, h...        02,05,09
# ...                                                   ...             ...
# 158506  05.05.05 -  Daisies  05.05.25 -  Other flowers...           05,26
# 158507  05.05.05 -  Daisies  05.05.25 -  Iris  (flower...              05
# 158508  01.01.13 -  Stars - multiple stars with five p...              01
# 158509  01.15.05 -  Vapor; Steam; Smoke  10.01.04 -  P...  01,10,23,24,26
# 158510  01.05.01 -  Sun, rising or setting (partially ...  01,03,05,06,26
#
#         target_h1_description  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 158506                    NaN
# 158507                    NaN
# 158508                    NaN
# 158509                    NaN
# 158510                    NaN
#
#                                               target_h2  \
# 0                                           02.03,02.09
# 1                                                 26.11
# 2                                                 02.03
# 3             01.15,02.05,02.09,10.03,19.07,26.11,26.15
# 4                                     02.03,05.03,09.01
# ...                                                 ...
# 158506                                      05.05,26.11
# 158507                                            05.05
# 158508                                            01.01
# 158509                    01.15,10.01,23.01,24.15,26.01
# 158510  01.05,03.15,03.19,05.01,05.07,05.13,06.03,26.01
#
#         target_h2_description  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 158506                    NaN
# 158507                    NaN
# 158508                    NaN
# 158509                    NaN
# 158510                    NaN
#
#                                                 target_h3  \
# 0                     02.03.04,02.03.14,02.03.21,02.09.06
# 1                                       26.11.10,26.11.21
# 2                                       02.03.01,02.03.15
# 3       01.15.07,02.05.04,02.09.06,10.03.03,19.07.25,2...
# 4                     02.03.13,02.03.25,05.03.10,09.01.04
# ...                                                   ...
# 158506                         05.05.05,05.05.25,26.11.01
# 158507                                  05.05.05,05.05.25
# 158508                                           01.01.13
# 158509       01.15.05,10.01.04,23.01.03,24.15.10,26.01.17
# 158510  01.05.01,03.15.01,03.19.25,05.01.01,05.07.07,0...
#
#                                     target_h3_description
# 0       02.03.04 - Women, Pilgrims, women in colonial ...
# 1       26.11.10 - Rectangles divided once into two se...
# 2       02.03.01 - Women - head, portraiture or busts ...
# 3       01.15.07 - Snow in a storm; Sleet; Rain; Hail ...
# 4       02.03.13 - Women, other women wearing folk, hi...
# ...                                                   ...
# 158506  05.05.05 - Daisies | 05.05.25 - Other flowers;...
# 158507  05.05.05 - Daisies | 05.05.25 - Iris  (flower)...
# 158508  01.01.13 - Stars - multiple stars with five po...
# 158509  01.15.05 - Vapor; Steam; Smoke | 10.01.04 - Pi...
# 158510  01.05.01 - Sun, rising or setting (partially e...
#
# [158511 rows x 9 columns]
